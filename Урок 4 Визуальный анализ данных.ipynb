# %% [markdown]
# # Задача 1
# Постройте график
# Назовите график
# Сделайте именование оси x и оси y
# Сделайте выводы
#
# 1.1. Скачать следующие данные: kc-house-data
# 1.2. Изучите стоимости недвижимости
# 1.3. Изучите распределение квадратуры жилой
# 1.4. Изучите распределение года постройки

# %%
import pandas as pd

# %%
df = pd.read_csv("sample_data/kc-house-data.csv")

# %% [markdown]
# ## Изучить описательную статистику стоимости недвижимости

# %%
df["price"].describe()
# Out:
# count    2.161300e+04
# mean     5.400881e+05
# std      3.671272e+05
# min      7.500000e+04
# 25%      3.219500e+05
# 50%      4.500000e+05
# 75%      6.450000e+05
# max      7.700000e+06
# Name: price, dtype: float64

# %% [markdown]
# ## Построить гистограмму стоимости недвижимости

# %%
df["price"].hist(bins=100)
# Out:
# <Axes: >

# %% [markdown]
# ## Изучить описательную статистику квадратуры жилой

# %%
df["sqft_living"].describe()
# Out:
# count    21613.000000
# mean      2079.899736
# std        918.440897
# min        290.000000
# 25%       1427.000000
# 50%       1910.000000
# 75%       2550.000000
# max      13540.000000
# Name: sqft_living, dtype: float64

# %% [markdown]
# ## Построить гистограмму квадратуры жилой

# %%
df["sqft_living"].hist(bins=100)
# Out:
# <Axes: >

# %% [markdown]
# ## Изучить описательную статистику года постройки

# %%
df["yr_built"].describe()
# Out:
# count    21613.000000
# mean      1971.005136
# std         29.373411
# min       1900.000000
# 25%       1951.000000
# 50%       1975.000000
# 75%       1997.000000
# max       2015.000000
# Name: yr_built, dtype: float64

# %% [markdown]
# ## Построить гистограмму года постройки

# %%
df["yr_built"].hist(bins=100)
# Out:
# <Axes: >

# %% [markdown]
# # Задача 2
# 2.1. Изучите распределение домов от наличия вида на набережную
# Постройте график
# Сделайте выводы
# 2.2. Изучите распределение этажей домов
# 2.3. Изучите распределение состояния домов

# %% [markdown]
# ##Выводы:
# - Большинство домов в наборе данных продаются по цене от 500 000 до 850 000 долларов. Есть небольшое количество домов, которые продаются по цене более 1 миллиона долларов.
# - Большинство домов в наборе данных имеют квадратуру жилой от 1500 до 2500 квадратов.
# - Большинство домов в наборе данных были построены в период с 1970 по 1985 год

# %% [markdown]
# ## Изучить распределение домов от наличия вида на набережную

# %%
df["view"].value_counts().plot(kind="bar", title="Распределение домов от наличия вида на набережную")
# Out:
# <Axes: title={'center': 'Распределение домов от наличия вида на набережную'}>

# %% [markdown]
# ## Изучить распределение этажей домов

# %%
df["floors"].value_counts().plot(kind="bar", title="Распределение этажей домов")
# Out:
# <Axes: title={'center': 'Распределение этажей домов'}>

# %% [markdown]
# ## Изучить распределение состояния домов

# %%
df["condition"].value_counts().plot(kind="bar", title="Распределение состояния домов")
# Out:
# <Axes: title={'center': 'Распределение состояния домов'}>

# %% [markdown]
# ##Выводы:
# - Большинство домов не имеют вида на набережную
# - Большинство домов имеют 2 этажа
# - Большинство домов находятся в хорошем состоянии

# %% [markdown]
# # Задача 3
# Исследуйте, какие характеристики недвижимости влияют на стоимость недвижимости, с применением не менее 5 диаграмм из урока.
# Анализ сделайте в формате storytelling: дополнить каждый график письменными выводами и наблюдениями.

# %% [markdown]
# ## Исследование влияния характеристик недвижимости на стоимость недвижимости
#
# В данном исследовании мы рассмотрим, какие характеристики недвижимости влияют на ее стоимость.
#
# 1. Распределение стоимости недвижимости
#
# На первом шаге мы рассмотрим распределение стоимости недвижимости. Для этого построим гистограмму стоимости недвижимости.
#
# Вывод:
#
# Стоимость недвижимости в наборе данных варьируется от 221 900 до 10 100 000 долларов.
# Медианная стоимость недвижимости составляет 625 000 долларов.
# Большинство домов в наборе данных продаются по цене от 500 000 до 800 000 долларов.
#
# 2. Влияние жилой площади на стоимость недвижимости
#
# На втором шаге мы рассмотрим влияние жилой площади на стоимость недвижимости. Для этого построим диаграмму рассеяния стоимости недвижимости и площади жилой.
#
# Вывод:
#
# Существует прямая зависимость между жилой площадью и стоимостью недвижимости.
# Чем больше жилая площадь, тем выше стоимость недвижимости.
#
# 4. Влияние года постройки на стоимость недвижимости
#
# На четвертом шаге мы рассмотрим влияние года постройки на стоимость недвижимости. Для этого построим диаграмму рассеяния стоимости недвижимости и года постройки.
#
# Вывод:
#
# Существует обратная зависимость между годом постройки и стоимостью недвижимости.
# Чем старше дом, тем ниже его стоимость.
#
# 5. Влияние наличия вида на набережную на стоимость недвижимости
#
# На пятом шаге мы рассмотрим влияние наличия вида на набережную на стоимость недвижимости. Для этого построим гистограмму стоимости недвижимости в зависимости от наличия вида на набережную.
#
# Вывод: дома с видом на набережную стоят дороже домов без вида на набережную.
